# %% [markdown]
# <a href="https://colab.research.google.com/github/AffanSurya/SenakApp_ML/blob/main/Model/Cleansing_dataset.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
df_recipes = pd.read_csv('//content/drive/MyDrive/Capstone/recipes.csv')
df_reviews = pd.read_csv('//content/drive/MyDrive/Capstone/reviews.csv')

# %% [markdown]
# # Recipes

# %%
# Menampilkan total baris
total_rows = df_recipes.shape[0]
print(f"Total baris dalam dataset: {total_rows}")
# Out:
# Total baris dalam dataset: 522517

# %%
pd.set_option('display.max_columns',30)
df_recipes.head(5)
# Out:
#    RecipeId                               Name  AuthorId      AuthorName  \
# 0        38  Low-Fat Berry Blue Frozen Dessert      1533          Dancer
# 1        39                            Biryani      1567        elly9812
# 2        40                      Best Lemonade      1566  Stephen Little
# 3        41     Carina's Tofu-Vegetable Kebabs      1586         Cyclopz
# 4        42                       Cabbage Soup      1538       Duckie067
#
#   CookTime PrepTime TotalTime         DatePublished  \
# 0    PT24H    PT45M  PT24H45M  1999-08-09T21:46:00Z
# 1    PT25M     PT4H   PT4H25M  1999-08-29T13:12:00Z
# 2     PT5M    PT30M     PT35M  1999-09-05T19:52:00Z
# 3    PT20M    PT24H  PT24H20M  1999-09-03T14:54:00Z
# 4    PT30M    PT20M     PT50M  1999-09-19T06:19:00Z
#
#                                          Description  \
# 0  Make and share this Low-Fat Berry Blue Frozen ...
# 1  Make and share this Biryani recipe from Food.com.
# 2  This is from one of my  first Good House Keepi...
# 3  This dish is best prepared a day in advance to...
# 4  Make and share this Cabbage Soup recipe from F...
#
#                                               Images   RecipeCategory  \
# 0  c("https://img.sndimg.com/food/image/upload/w_...  Frozen Desserts
# 1  c("https://img.sndimg.com/food/image/upload/w_...   Chicken Breast
# 2  c("https://img.sndimg.com/food/image/upload/w_...        Beverages
# 3  c("https://img.sndimg.com/food/image/upload/w_...         Soy/Tofu
# 4  "https://img.sndimg.com/food/image/upload/w_55...        Vegetable
#
#                                             Keywords  \
# 0  c("Dessert", "Low Protein", "Low Cholesterol",...
# 1  c("Chicken Thigh & Leg", "Chicken", "Poultry",...
# 2  c("Low Protein", "Low Cholesterol", "Healthy",...
# 3  c("Beans", "Vegetable", "Low Cholesterol", "We...
# 4  c("Low Protein", "Vegan", "Low Cholesterol", "...
#
#                           RecipeIngredientQuantities  \
# 0                            c("4", "1/4", "1", "1")
# 1  c("1", "4", "2", "2", "8", "1/4", "8", "1/2", ...
# 2            c("1 1/2", "1", NA, "1 1/2", NA, "3/4")
# 3  c("12", "1", "2", "1", "10", "1", "3", "2", "2...
# 4                        c("46", "4", "1", "2", "1")
#
#                                RecipeIngredientParts  AggregatedRating  \
# 0  c("blueberries", "granulated sugar", "vanilla ...               4.5
# 1  c("saffron", "milk", "hot green chili peppers"...               3.0
# 2  c("sugar", "lemons, rind of", "lemon, zest of"...               4.5
# 3  c("extra firm tofu", "eggplant", "zucchini", "...               4.5
# 4  c("plain tomato juice", "cabbage", "onion", "c...               4.5
#
#    ReviewCount  Calories  FatContent  SaturatedFatContent  CholesterolContent  \
# 0          4.0     170.9         2.5                  1.3                 8.0
# 1          1.0    1110.7        58.8                 16.6               372.8
# 2         10.0     311.1         0.2                  0.0                 0.0
# 3          2.0     536.1        24.0                  3.8                 0.0
# 4         11.0     103.6         0.4                  0.1                 0.0
#
#    SodiumContent  CarbohydrateContent  FiberContent  SugarContent  \
# 0           29.8                 37.1           3.6          30.2
# 1          368.4                 84.4           9.0          20.4
# 2            1.8                 81.5           0.4          77.2
# 3         1558.6                 64.2          17.3          32.1
# 4          959.3                 25.1           4.8          17.7
#
#    ProteinContent  RecipeServings RecipeYield  \
# 0             3.2             4.0         NaN
# 1            63.4             6.0         NaN
# 2             0.3             4.0         NaN
# 3            29.3             2.0    4 kebabs
# 4             4.3             4.0         NaN
#
#                                   RecipeInstructions
# 0  c("Toss 2 cups berries with sugar.", "Let stan...
# 1  c("Soak saffron in warm milk for 5 minutes and...
# 2  c("Into a 1 quart Jar with tight fitting lid, ...
# 3  c("Drain the tofu, carefully squeezing out exc...
# 4  c("Mix everything together and bring to a boil...

# %%
df_recipes.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 522517 entries, 0 to 522516
# Data columns (total 28 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   RecipeId                    522517 non-null  int64
#  1   Name                        522517 non-null  object
#  2   AuthorId                    522517 non-null  int64
#  3   AuthorName                  522517 non-null  object
#  4   CookTime                    439972 non-null  object
#  5   PrepTime                    522517 non-null  object
#  6   TotalTime                   522517 non-null  object
#  7   DatePublished               522517 non-null  object
#  8   Description                 522512 non-null  object
#  9   Images                      522516 non-null  object
#  10  RecipeCategory              521766 non-null  object
#  11  Keywords                    505280 non-null  object
#  12  RecipeIngredientQuantities  522514 non-null  object
#  13  RecipeIngredientParts       522517 non-null  object
#  14  AggregatedRating            269294 non-null  float64
#  15  ReviewCount                 275028 non-null  float64
#  16  Calories                    522517 non-null  float64
#  17  FatContent                  522517 non-null  float64
#  18  SaturatedFatContent         522517 non-null  float64
#  19  CholesterolContent          522517 non-null  float64
#  20  SodiumContent               522517 non-null  float64
#  21  CarbohydrateContent         522517 non-null  float64
#  22  FiberContent                522517 non-null  float64
#  23  SugarContent                522517 non-null  float64
#  24  ProteinContent              522517 non-null  float64
#  25  RecipeServings              339606 non-null  float64
#  26  RecipeYield                 174446 non-null  object
#  27  RecipeInstructions          522517 non-null  object
# dtypes: float64(12), int64(2), object(14)
# memory usage: 111.6+ MB

# %%
# Menghapus baris yang tidak memiliki link gambar
df_recipes = df_recipes[df_recipes['Images'].notna()]

# Menghapus baris dengan nilai "(0)" atau karakter kosong pada kolom "Images"
df_recipes = df_recipes[df_recipes['Images'] != 'character(0)']

# Menghapus baris yang memiliki ReviewCount di bawah 10
df_recipes = df_recipes[df_recipes['ReviewCount'] >= 10]

# Menghapus kolom-kolom yang diminta
columns_to_drop = ['AuthorName', 'CookTime', 'PrepTime', 'TotalTime', 'DatePublished', 'RecipeYield', 'Keywords', 'RecipeServings']
df_recipes = df_recipes.drop(columns=columns_to_drop, errors='ignore')

# %%
df_recipes = df_recipes.rename(columns={
    'FatContent': 'Fat',
    'SaturatedFatContent': 'SaturatedFat',
    'CholesterolContent': 'Cholesterol',
    'SodiumContent': 'Sodium',
    'CarbohydrateContent': 'Carbohydrate',
    'FiberContent': 'Fiber',
    'SugarContent': 'Sugar',
    'ProteinContent': 'Protein'
})

# %%
df_recipes['Description'] = df_recipes['Description'].replace('from Food.com', '', regex=True)

# %%
# Menampilkan nama yang duplikat
duplicate_names = df_recipes[df_recipes.duplicated(subset='Name', keep=False)]['Name'].unique()

# Menampilkan hasil
print("Nama yang duplikat:")
print(duplicate_names)
# Out:
# Nama yang duplikat:
# ['Cabbage Soup' 'Carrot Cake' 'Alfredo Sauce' 'Chicken Curry'
#  'Anzac Biscuits' 'Chocolate Zucchini Bread' 'Twice Baked Potatoes'
#  'Brown Sugar Shortbread' 'Moussaka' 'Olive Garden Pasta E Fagioli'
#  'Irish Soda Bread' 'Garlic Cauliflower' 'Greek Salad Dressing'
#  'Corn Fritters' 'English Muffins' 'Egg Drop Soup' 'Hot Cocoa Mix'
#  'Mexican Hamburgers' 'Oatmeal Muffins' 'Beef Enchiladas' 'Spaghetti Pie'
#  'Taco Seasoning' 'Strawberry Lemonade' 'Rhubarb Crunch'
#  'Peanut Butter Pie' 'Stuffed Zucchini' 'Taco Seasoning Mix'
#  'Hot Pizza Dip' 'Best Banana Bread' 'Macaroni and Cheese' 'Paella'
#  'Mashed Potatoes' 'Sugar Cookies' 'German Chocolate Cake'
#  'Beef Stroganoff' 'French Toast' 'Pumpkin Chocolate Chip Muffins'
#  'Potato Soup' 'Chicken Cheese Lasagna' 'Chicken Gumbo'
#  'Oven Fried Chicken' 'Spaghetti Sauce'
#  'Easy Crock Pot Chicken Cacciatore' 'Baklava' 'Pumpkin Puree'
#  'Crock Pot Beef Stroganoff' 'Sweet Potato & Pear Soup'
#  'Chewy Chocolate Cookies' 'Broccoli Casserole' 'Cinnamon French Toast'
#  'Spinach and Strawberry Salad' 'Apple Muffins' 'Pavlova'
#  'Oatmeal Raisin Cookies' 'Roasted Garlic' 'Apple Bread'
#  'Cream of Broccoli Soup' 'Beer Bread' 'Amaretto Coffee' 'Pumpkin Muffins'
#  'Zucchini Fritters' 'Herbed Corn on the Cob' 'Spinach Quiche' 'Lasagna'
#  'Baked Tomatoes' 'Chicken Cordon Bleu' 'Grilled Salmon'
#  'Marinade for Steak' 'Pizza Dough' 'Chicken Stir-Fry' 'Fried Rice'
#  'Macaroni Salad' 'Cheese Stuffed Shells' 'Chicken Piccata'
#  "Granny's Sugar Cookies" 'Grilled Potatoes' 'Asparagus Risotto'
#  'Baked Beans' "Mom's Molasses Cookies" 'Kentucky Butter Cake'
#  'Cream Cheese Pound Cake' 'Tilapia' 'Sour Cream Banana Bread'
#  'Zucchini Parmesan' 'Cheesecake' 'Rice Pudding' 'Banana Nut Bread'
#  'Banana Muffins' 'Bourbon Steak' 'Banana Bread' 'Greek Chicken'
#  'Garlic Bread' 'Chocolate Chip Banana Bread' 'Taco Soup'
#  'Sesame Broccoli' 'Guacamole' 'Banana Cake' 'Playdough' 'Spinach Dip'
#  'Lemon Bars' '5-Ingredient Strawberry Pie' 'Peanut Butter Cookies'
#  'Brownies' 'Lemon Garlic Chicken' 'Crab Rangoon' 'Broccoli Salad'
#  'Greek Salad' 'Breakfast Casserole' 'No-Fail Pie Crust' 'Tiramisu'
#  'Lemon Chicken' 'Hummus' 'Tomato Pie' 'Stuffed Mushrooms'
#  'Gingerbread Waffles' 'Cashew Chicken' 'Easy Pot Roast'
#  'Stuffed Bell Peppers' 'Cabbage Casserole' 'Pepper Steak' 'Granola Bars'
#  'Pina Colada' 'Apple Crisp' 'Sweet Potato Wedges' 'Bisquick Clone'
#  'Mongolian Beef' 'Caribbean Shrimp' 'Pesto' 'Cranberry Scones'
#  'Pumpkin Eggnog Pie' 'Snickerdoodles' 'Garlic Potatoes' 'Pumpkin Bread'
#  'Texas Sheet Cake' 'Mexican Manicotti' 'Creamy Tomato Soup'
#  'Pumpkin Pie Pudding' 'Italian Wedding Soup' 'Sesame Chicken'
#  'Vegan Pumpkin Pie' 'Coconut Macaroons'
#  'Overnight Blueberry French Toast' 'Jalapeno Poppers' 'Caramel Popcorn'
#  'Enchilada Casserole' 'Herbed Pork Chops' 'Cake Mix Cookies'
#  'Oven Fried Sesame Chicken' 'Hamburger Gravy' 'Fluffy Pancakes'
#  'German Pancake' 'Curried Couscous' 'Honey Butter' 'Fried Cabbage'
#  'Zucchini Bread' 'Smothered Pork Chops' 'Cucumber and Onion Salad'
#  'Cream of Asparagus Soup' 'Chickpea Salad' 'My Favorite Chili'
#  'Hot and Sour Soup' 'Flourless Peanut Butter Cookies' 'Mexican Lasagna'
#  'Lemon Squares' 'Meatballs' 'Sour Cream Coffee Cake'
#  'Cream Cheese Cookies' 'Chicken Noodle Soup' 'Fish and Chips'
#  'Chicken Enchiladas' "Mom's Potato Salad" 'Strawberry Bread'
#  'Baked Potato Salad' 'Caramel Squares' 'Dumplings' 'Ranch Potatoes'
#  'Tartar Sauce' 'Oyster Stew' 'Sausage Bread' 'Steak Diane'
#  'Banana Coconut Muffins' 'Banana Milkshake' 'Cordon Bleu Casserole'
#  'Blueberry Bundt Cake' 'Caramel Apple Salad' 'Maple-Glazed Carrots'
#  'Eggplant (Aubergine) Parmesan' 'Skillet Lasagna' 'Whole Wheat Pancakes'
#  'Chocolate Chip Cookies' 'Apple Cake' 'Cinnamon Muffins' 'Cucumber Salad'
#  'Krispy Kreme Doughnuts' 'Mexican Cornbread' 'Honey Cornbread'
#  'Butter Chicken' 'Play Dough' 'Blueberry Muffins' 'Applesauce Cake'
#  'Slow Cooker Lasagna' 'Lemonade' 'Peanut Butter Brownies'
#  'Chicken Paprikash' 'Garlic Soup' 'Banana Pancakes' 'Pasta Puttanesca'
#  'Spiced Couscous' 'Creamy Coleslaw' 'Blueberry Pie'
#  'Easy Red Velvet Cake' 'Enchiladas' 'Garlic Chicken Pizza'
#  'Butterfinger Cookies' 'Apricot Carrots' 'Salmon Chowder'
#  'Roasted Asparagus' 'Sweet and Sour Pork' 'Vegetable Lo Mein'
#  'Sweet and Sour Chicken' 'Chocolate Pound Cake' 'Tender Sauteed Zucchini'
#  'Mexican Rice' 'Enchilada Pie' 'Szechuan Shrimp' 'Baked Oatmeal'
#  'Pancakes' 'Green Beans' 'Greek Tomato Salad' 'Bran Muffins'
#  'Tex-Mex Pork Chops' 'Veggie Burgers' 'Oven Barbecued Chicken'
#  'Chocolate Chip Oatmeal Cookies' 'Amish White Bread'
#  'Roasted Red Potatoes' 'Baked Ziti' 'Soft Ginger Cookies'
#  'Herb Roasted Potatoes' 'Hungarian Goulash' 'Salsa Chicken'
#  'Applesauce Muffins' 'Cinnamon Coffee Cake' 'Pot Roast'
#  'White Texas Sheet Cake' 'Buttermilk Biscuits' 'Cheddar-Garlic Biscuits'
#  'Cilantro Rice' 'Oatmeal Cookies' 'Unstuffed Cabbage Rolls'
#  'Red Lentil Soup' 'Oatmeal Peanut Butter Chocolate Chip Cookies'
#  'Buffalo Wings' 'Beef Stew' 'Watermelon Lemonade' "Farmer's Breakfast"
#  'Salisbury Steak' 'Lemon Crinkle Cookies' 'Baked Pork Chops'
#  'Chicken Souvlaki' 'Cauliflower Casserole' 'Easy Chicken Noodle Soup'
#  'Amish Baked Oatmeal' 'Potato Pancakes' 'Bread Pudding' 'Pickled Beets'
#  'Chocolate Frosting' 'Peach Cobbler' 'Flour Tortillas' 'Pork Fried Rice'
#  'Cookie Dough Brownies' 'Antipasto Pasta Salad' 'Scalloped Potatoes'
#  'Chicken Stroganoff' 'Peanut Butter Frosting' 'Raspberry Sauce'
#  'Watermelon Smoothie' 'Mexican Hot Chocolate' 'Egg Bread'
#  'Vietnamese Spring Rolls' 'Blueberry Streusel Muffins'
#  'Butternut Squash Soup' 'Tomato Salad' 'Chinese Spaghetti'
#  'Peanut Butter Banana Cookies' 'Blueberry Oat Muffins' 'Spicy Guacamole'
#  'Sauteed Mushrooms' 'Pita Pizza' 'Pumpkin Pancakes' 'Baked Potato Soup'
#  'Split Pea Soup' 'Easy Dinner Rolls' 'Tomato Soup' 'Baked Potato Wedges'
#  'Black Bottom Cupcakes' 'Turkey Meatloaf' 'Wonton Soup'
#  'Watermelon Juice' 'Kung Pao Chicken' 'Butter Pecan Cake'
#  'Pineapple Upside Down Cake' 'Honey Baked Chicken'
#  'Crock Pot Chicken Cacciatore' "Santa's Whiskers" 'Italian Bread'
#  'Gingerbread Pancakes' 'Blueberry Pancakes' 'Chicken Enchilada Casserole'
#  'Balsamic Vinaigrette' 'Raspberry Lemon Muffins'
#  'Italian Sausage and Tortellini Soup' 'Pumpkin Cookies'
#  'Cajun Pork Chops' 'Scones' 'Waffles' 'Garlic Green Beans'
#  'Turkey Pot Pie' 'Sweet Potato Fries' 'Italian Salad Dressing'
#  'Snickerdoodle Cookies' 'Mahogany Chicken Wings' 'Corn Dog Muffins'
#  'Sweet Potato Bake' 'Colcannon' 'Garlic Fries' 'Apple Pie'
#  'Sausage Balls' 'Leek and Potato Soup' 'Lemon Curd' 'Unstuffed Cabbage'
#  'Cocoa Brownies' 'Pasta Salad' 'Saffron Rice' 'Coleslaw' 'Deviled Eggs'
#  'Eggplant Casserole' 'Ritz Cookies' 'Teriyaki Sauce' 'Mexican Casserole'
#  'Roasted Potatoes' 'Moroccan Carrot Salad' 'Potato Sausage Soup'
#  'Buttermilk Pancakes' 'Greek Chicken Salad'
#  'Peanut Butter Chocolate Chip Cookies' 'Pita Chips' 'Coffee Cake Muffins'
#  'Crusty Baked Potatoes' 'Tzatziki' 'Strawberry Pie' 'Mushroom Risotto'
#  'Baked Parmesan Fish' 'Hush Puppies' 'Roasted Lemon Chicken'
#  'Beef Taco Bake' 'Pretzels' 'Coconut Basmati Rice'
#  'Cream Cheese Frosting' 'Strawberry Jam' 'Lemon Meringue Pie'
#  'Gingersnaps' 'Boston Cream Pie' 'Yorkshire Pudding'
#  'Brown Sugar Cookies' 'Cheese Bread' 'Pumpkin Chocolate Chip Cookies'
#  'Spanish Rice' 'Cheese Ball' 'Chicken Salad' 'Greek Pita Bread'
#  'Apple Crumble' 'Greek Seasoning Mix' 'Cinnamon Toast' 'Garlic Chicken'
#  'BBQ Chicken Pizza' 'Rissoles' 'Brussels Sprouts' 'Chicken Satay'
#  'Bruschetta Chicken' 'Mango Bread' 'Peanut Butter Banana Muffins'
#  'Blackened Chicken' 'Peanut Butter Muffins' 'Cornbread' 'Almond Tea'
#  'Lime Cola' 'Peasant Bread' 'Chicken Chow Mein'
#  'Vegan Chocolate Chip Cookies' 'Peanut Butter Fudge'
#  'Banana Buttermilk Pancakes' 'Banana Bread Oatmeal' 'Cauliflower Salad'
#  'Black Bean Hummus' 'Chicken and Dumplings' 'Pot Sticker Dipping Sauce'
#  'Cheeseburger Pasta' 'Best Baked Ziti' 'Biscuits'
#  'Crock Pot Baked Potatoes' 'Braised Lamb Shanks' 'Eclair Cake'
#  'Strawberry Shortcake Muffins' 'Rolo Cookies' 'Spicy Roasted Potatoes'
#  'Jam Drops' 'Smoked Salmon Spread' 'Ham and Noodle Casserole'
#  'Artichoke Bruschetta' 'Indian Butter Chicken' 'Cajun Remoulade Sauce'
#  'Sloppy Joes' 'Croutons' 'Thai Cucumber Salad' 'Chocolate Chip Scones'
#  'Cornucopia Salad' 'Cold Sesame Noodles' 'Egg Salad'
#  'Banana-Oatmeal Bread' 'Baked Garlic Green Beans'
#  'Sausage and Potato Soup' 'Glazed Carrots' 'Hawaiian Chicken'
#  'Roasted Cauliflower' 'Sticky Chicken' 'Salmon Dip' 'Dipped Gingersnaps'
#  'Honey Dijon Chicken' 'White Pizza' 'Garlic Mashed Potatoes' 'Tuna Melt'
#  'Peach Muffins' 'Smashed Potatoes' 'Egg and Bacon Tarts' 'Turkish Coffee'
#  'Banana Smoothie' 'Strawberry Margaritas' 'Sweet Potato Souffle'
#  'Crock Pot Mexican Chicken' 'Cilantro Lime Rice' 'Honeyed Carrots'
#  'Barbecue Baked Lentils' 'Croque Madame' 'Greek Scrambled Eggs'
#  'Moroccan Chicken' 'Watermelon Agua Fresca' 'Crash Hot Potatoes'
#  'Sweet and Sour Dipping Sauce' 'Eggnog Pancakes' 'Swedish Pancakes'
#  'Mint Limeade' 'Baked Bananas' 'Berry Smoothie' 'Pork Chops'
#  'Ginger Cookies' 'Blueberry Coffee Cake' 'Broccoli Dijon'
#  'Black Bean Brownies (Gluten Free)' 'Sauteed Zucchini' 'Beef Burgers'
#  'Banana Pancake' 'Belgian Carrots' 'Coconut Rice']

# %%
# Menghapus baris dengan nama yang duplikat
df_recipes = df_recipes.drop_duplicates(subset='Name', keep='first')

# %%
#check
check_rows = df_recipes.loc[df_recipes['Name'] == 'Hawaiian Chicken']
check_rows.head()
# Out:
#        RecipeId              Name  AuthorId  \
# 96660    102120  Hawaiian Chicken     80353
#
#                                              Description  \
# 96660  OK, it's the sauce that makes the chicken. Rea...
#
#                                                   Images RecipeCategory  \
# 96660  c("https://img.sndimg.com/food/image/upload/w_...        Chicken
#
#                               RecipeIngredientQuantities  \
# 96660  c("3", "1/4", "1/4", "1/2", "1/3", "1/2", "1/4...
#
#                                    RecipeIngredientParts  AggregatedRating  \
# 96660  c("chicken", "ketchup", "soy sauce", "chicken ...               4.0
#
#        ReviewCount  Calories   Fat  SaturatedFat  Cholesterol  Sodium  \
# 96660         10.0     660.0  34.4           9.8        170.1  1021.3
#
#        Carbohydrate  Fiber  Sugar  Protein  \
# 96660          30.4    0.3   26.5     44.4
#
#                                       RecipeInstructions
# 96660  c("Mix sauce ingredients in bowl; generously c...

# %%
df_recipes.head(5)
# Out:
#     RecipeId                      Name  AuthorId  \
# 2         40             Best Lemonade      1566
# 4         42              Cabbage Soup      1538
# 6         44    Warm Chicken A La King      1596
# 11        49  Chicken Breasts Lombardi    174711
# 16        54               Carrot Cake      1535
#
#                                           Description  \
# 2   This is from one of my  first Good House Keepi...
# 4           Make and share this Cabbage Soup recipe .
# 6   I copied this one out of a friend's book so ma...
# 11  Make and share this Chicken Breasts Lombardi r...
# 16  This is one of the few recipes my husband ever...
#
#                                                Images  RecipeCategory  \
# 2   c("https://img.sndimg.com/food/image/upload/w_...       Beverages
# 4   "https://img.sndimg.com/food/image/upload/w_55...       Vegetable
# 6   "https://img.sndimg.com/food/image/upload/w_55...         Chicken
# 11  c("https://img.sndimg.com/food/image/upload/w_...  Chicken Breast
# 16  c("https://img.sndimg.com/food/image/upload/w_...         Dessert
#
#                            RecipeIngredientQuantities  \
# 2             c("1 1/2", "1", NA, "1 1/2", NA, "3/4")
# 4                         c("46", "4", "1", "2", "1")
# 6   c("12", "2", "3", "450", "1", "2", "1/4", "1",...
# 11  c("2", "2", "12", "1/2", "1/3", "3/4", "1/2", ...
# 16  c("3", "4", "1 1/4", "2", "2", "2", "2", "1", ...
#
#                                 RecipeIngredientParts  AggregatedRating  \
# 2   c("sugar", "lemons, rind of", "lemon, zest of"...               4.5
# 4   c("plain tomato juice", "cabbage", "onion", "c...               4.5
# 6   c("chicken", "butter", "flour", "milk", "celer...               5.0
# 11  c("fresh mushrooms", "butter", "boneless skinl...               5.0
# 16  c("carrots", "eggs", "white sugar", "all-purpo...               5.0
#
#     ReviewCount  Calories   Fat  SaturatedFat  Cholesterol  Sodium  \
# 2          10.0     311.1   0.2           0.0          0.0     1.8
# 4          11.0     103.6   0.4           0.1          0.0   959.3
# 6          23.0     895.5  66.8          31.9        405.8   557.2
# 11         21.0     627.7  24.9          13.0        203.0   848.9
# 16         17.0     522.6  27.1           4.9         69.8   534.8
#
#     Carbohydrate  Fiber  Sugar  Protein  \
# 2           81.5    0.4   77.2      0.3
# 4           25.1    4.8   17.7      4.3
# 6           29.1    3.1    5.0     45.3
# 11          13.7    0.6    2.0     57.9
# 16          67.0    1.6   47.9      5.0
#
#                                    RecipeInstructions
# 2   c("Into a 1 quart Jar with tight fitting lid, ...
# 4   c("Mix everything together and bring to a boil...
# 6   c("Melt 1 1/2 ozs butter, add the flour and co...
# 11  c("Cook mushrooms in 2 tbsp butter in a large ...
# 16  c("Beat together the eggs, oil, and white suga...

# %%
# Tampilkan baris di mana 'RecipeIngredientQuantities' mengandung huruf NA
df_with_na = df_recipes[df_recipes['RecipeIngredientQuantities'].str.contains('NA')]

print(df_with_na.shape[0])
# Out:
# 8051

# %%
# Hapus baris di mana 'RecipeIngredientQuantities' mengandung huruf NA
df_recipes = df_recipes[~df_recipes['RecipeIngredientQuantities'].str.contains('NA')]

df_recipes.head(5)
# Out:
#     RecipeId                         Name  AuthorId  \
# 4         42                 Cabbage Soup      1538
# 11        49     Chicken Breasts Lombardi    174711
# 16        54                  Carrot Cake      1535
# 18        56               Buttermilk Pie      1581
# 27        66  Black Coffee Barbecue Sauce    174711
#
#                                           Description  \
# 4           Make and share this Cabbage Soup recipe .
# 11  Make and share this Chicken Breasts Lombardi r...
# 16  This is one of the few recipes my husband ever...
# 18  This recipe was originally noted by my wife on...
# 27  It's great to know folks like this sauce so mu...
#
#                                                Images  RecipeCategory  \
# 4   "https://img.sndimg.com/food/image/upload/w_55...       Vegetable
# 11  c("https://img.sndimg.com/food/image/upload/w_...  Chicken Breast
# 16  c("https://img.sndimg.com/food/image/upload/w_...         Dessert
# 18  c("https://img.sndimg.com/food/image/upload/w_...             Pie
# 27  c("https://img.sndimg.com/food/image/upload/w_...    Lactose Free
#
#                            RecipeIngredientQuantities  \
# 4                         c("46", "4", "1", "2", "1")
# 11  c("2", "2", "12", "1/2", "1/3", "3/4", "1/2", ...
# 16  c("3", "4", "1 1/4", "2", "2", "2", "2", "1", ...
# 18    c("1/2", "1 1/2", "3", "3", "1", "1", "1", "1")
# 27  c("1/2", "1", "1/4", "3/4", "1", "2", "2", "2"...
#
#                                 RecipeIngredientParts  AggregatedRating  \
# 4   c("plain tomato juice", "cabbage", "onion", "c...               4.5
# 11  c("fresh mushrooms", "butter", "boneless skinl...               5.0
# 16  c("carrots", "eggs", "white sugar", "all-purpo...               5.0
# 18  c("butter", "margarine", "sugar", "flour", "eg...               5.0
# 27  c("brewed coffee", "ketchup", "red wine vinega...               5.0
#
#     ReviewCount  Calories   Fat  SaturatedFat  Cholesterol  Sodium  \
# 4          11.0     103.6   0.4           0.1          0.0   959.3
# 11         21.0     627.7  24.9          13.0        203.0   848.9
# 16         17.0     522.6  27.1           4.9         69.8   534.8
# 18        171.0     395.9  19.1           9.8        101.5   269.8
# 27         19.0     772.0   3.9           0.5          0.0  2241.9
#
#     Carbohydrate  Fiber  Sugar  Protein  \
# 4           25.1    4.8   17.7      4.3
# 11          13.7    0.6    2.0     57.9
# 16          67.0    1.6   47.9      5.0
# 18          52.2    0.7   39.9      5.0
# 27         189.6    6.4  164.3      7.0
#
#                                    RecipeInstructions
# 4   c("Mix everything together and bring to a boil...
# 11  c("Cook mushrooms in 2 tbsp butter in a large ...
# 16  c("Beat together the eggs, oil, and white suga...
# 18  c("Preheat oven to 400°F.", "Beat the butter a...
# 27  c("Combine all ingredients in a saucepan and s...

# %%
# Menampilkan total baris
total_rows = df_recipes.shape[0]
print(f"Total baris dalam dataset: {total_rows}")
# Out:
# Total baris dalam dataset: 15848

# %% [markdown]
# ------------------------------------------

# %% [markdown]
# # Reviews

# %%
# Menampilkan total baris
total_rows = df_reviews.shape[0]
print(f"Total baris dalam dataset: {total_rows}")
# Out:
# Total baris dalam dataset: 1401982

# %%
df_reviews = pd.merge(df_reviews, df_recipes[['RecipeId', 'Name']], on='RecipeId', how='left')

# %%
name_column = df_reviews.pop('Name')
df_reviews.insert(1, 'Name', name_column)

# %%
# Menghapus baris yang tidak memiliki link gambar
df_reviews = df_reviews[df_reviews['Name'].notna()]

# %%
df_reviews.head(5)
# Out:
#     ReviewId                                              Name  RecipeId  \
# 5         17                      Spinach and Strawberry Salad      5221
# 6         19  Neiman-Marcus $250 Chocolate Chip Cookies Recipe     13307
# 10        24                           Greek Spinach Triangles       278
# 12        26                      Spinach and Strawberry Salad      5221
# 15        36                                 Fresh Peach Crisp      7478
#
#     AuthorId           AuthorName  Rating  \
# 5       2046     Gay Gilmore ckpt       4
# 6       2046     Gay Gilmore ckpt       5
# 10      1773        Malarkey Test       4
# 12      2369       William Hakala       5
# 15      2585  Jennifer Kurzdorfer       4
#
#                                                Review         DateSubmitted  \
# 5              love it, but without the bean sprouts.  2000-05-08T11:08:00Z
# 6   chewy goodness, not crispy at all. i even thre...  2000-05-21T16:59:00Z
# 10   a little greasy, but a huge hit with the guests.  2000-03-13T19:53:00Z
# 12  I deleted the bean sprouts and replaced them w...  2000-07-18T13:36:56Z
# 15  Very simple recipe to make! This is a refreshi...  2000-09-05T13:27:34Z
#
#             DateModified
# 5   2000-05-08T11:08:00Z
# 6   2000-05-21T16:59:00Z
# 10  2000-03-13T19:53:00Z
# 12  2000-07-18T13:36:56Z
# 15  2000-09-05T13:27:34Z

# %%
df_reviews.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 492949 entries, 5 to 1401980
# Data columns (total 9 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   ReviewId       492949 non-null  int64
#  1   Name           492949 non-null  object
#  2   RecipeId       492949 non-null  int64
#  3   AuthorId       492949 non-null  int64
#  4   AuthorName     492949 non-null  object
#  5   Rating         492949 non-null  int64
#  6   Review         492825 non-null  object
#  7   DateSubmitted  492949 non-null  object
#  8   DateModified   492949 non-null  object
# dtypes: int64(4), object(5)
# memory usage: 37.6+ MB

# %%
columns_to_drop = ['AuthorName']
df_reviews = df_reviews.drop(columns=columns_to_drop, errors='ignore')

# %%
# Menampilkan total baris
total_rows = df_reviews.shape[0]
print(f"Total baris dalam dataset: {total_rows}")
# Out:
# Total baris dalam dataset: 492949

# %% [markdown]
# # Save File

# %%
# df_reviews.to_csv('/content/drive/MyDrive/Capstone/reviews_reduce.csv', index=False)

# %%
# df_recipes.to_csv('/content/drive/MyDrive/Capstone/recipes_reduce.csv', index=False)
