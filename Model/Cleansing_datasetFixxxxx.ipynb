# %% [markdown]
# <a href="https://colab.research.google.com/github/AffanSurya/SenakApp_ML/blob/main/Model/Cleansing_datasetFixxxxx.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import re

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
df_recipes = pd.read_csv('/content/drive/MyDrive/Dataset/recipes.csv')
df_reviews = pd.read_csv('/content/drive/MyDrive/Dataset/reviews.csv')

# %% [markdown]
# # Recipes

# %%
# Menampilkan total baris
total_rows = df_recipes.shape[0]
print(f"Total baris dalam dataset: {total_rows}")
# Out:
# Total baris dalam dataset: 522517

# %%
pd.set_option('display.max_columns',30)
df_recipes.head(5)
# Out:
#    RecipeId                               Name  AuthorId      AuthorName  \
# 0        38  Low-Fat Berry Blue Frozen Dessert      1533          Dancer
# 1        39                            Biryani      1567        elly9812
# 2        40                      Best Lemonade      1566  Stephen Little
# 3        41     Carina's Tofu-Vegetable Kebabs      1586         Cyclopz
# 4        42                       Cabbage Soup      1538       Duckie067
#
#   CookTime PrepTime TotalTime         DatePublished  \
# 0    PT24H    PT45M  PT24H45M  1999-08-09T21:46:00Z
# 1    PT25M     PT4H   PT4H25M  1999-08-29T13:12:00Z
# 2     PT5M    PT30M     PT35M  1999-09-05T19:52:00Z
# 3    PT20M    PT24H  PT24H20M  1999-09-03T14:54:00Z
# 4    PT30M    PT20M     PT50M  1999-09-19T06:19:00Z
#
#                                          Description  \
# 0  Make and share this Low-Fat Berry Blue Frozen ...
# 1  Make and share this Biryani recipe from Food.com.
# 2  This is from one of my  first Good House Keepi...
# 3  This dish is best prepared a day in advance to...
# 4  Make and share this Cabbage Soup recipe from F...
#
#                                               Images   RecipeCategory  \
# 0  c("https://img.sndimg.com/food/image/upload/w_...  Frozen Desserts
# 1  c("https://img.sndimg.com/food/image/upload/w_...   Chicken Breast
# 2  c("https://img.sndimg.com/food/image/upload/w_...        Beverages
# 3  c("https://img.sndimg.com/food/image/upload/w_...         Soy/Tofu
# 4  "https://img.sndimg.com/food/image/upload/w_55...        Vegetable
#
#                                             Keywords  \
# 0  c("Dessert", "Low Protein", "Low Cholesterol",...
# 1  c("Chicken Thigh & Leg", "Chicken", "Poultry",...
# 2  c("Low Protein", "Low Cholesterol", "Healthy",...
# 3  c("Beans", "Vegetable", "Low Cholesterol", "We...
# 4  c("Low Protein", "Vegan", "Low Cholesterol", "...
#
#                           RecipeIngredientQuantities  \
# 0                            c("4", "1/4", "1", "1")
# 1  c("1", "4", "2", "2", "8", "1/4", "8", "1/2", ...
# 2            c("1 1/2", "1", NA, "1 1/2", NA, "3/4")
# 3  c("12", "1", "2", "1", "10", "1", "3", "2", "2...
# 4                        c("46", "4", "1", "2", "1")
#
#                                RecipeIngredientParts  AggregatedRating  \
# 0  c("blueberries", "granulated sugar", "vanilla ...               4.5
# 1  c("saffron", "milk", "hot green chili peppers"...               3.0
# 2  c("sugar", "lemons, rind of", "lemon, zest of"...               4.5
# 3  c("extra firm tofu", "eggplant", "zucchini", "...               4.5
# 4  c("plain tomato juice", "cabbage", "onion", "c...               4.5
#
#    ReviewCount  Calories  FatContent  SaturatedFatContent  CholesterolContent  \
# 0          4.0     170.9         2.5                  1.3                 8.0
# 1          1.0    1110.7        58.8                 16.6               372.8
# 2         10.0     311.1         0.2                  0.0                 0.0
# 3          2.0     536.1        24.0                  3.8                 0.0
# 4         11.0     103.6         0.4                  0.1                 0.0
#
#    SodiumContent  CarbohydrateContent  FiberContent  SugarContent  \
# 0           29.8                 37.1           3.6          30.2
# 1          368.4                 84.4           9.0          20.4
# 2            1.8                 81.5           0.4          77.2
# 3         1558.6                 64.2          17.3          32.1
# 4          959.3                 25.1           4.8          17.7
#
#    ProteinContent  RecipeServings RecipeYield  \
# 0             3.2             4.0         NaN
# 1            63.4             6.0         NaN
# 2             0.3             4.0         NaN
# 3            29.3             2.0    4 kebabs
# 4             4.3             4.0         NaN
#
#                                   RecipeInstructions
# 0  c("Toss 2 cups berries with sugar.", "Let stan...
# 1  c("Soak saffron in warm milk for 5 minutes and...
# 2  c("Into a 1 quart Jar with tight fitting lid, ...
# 3  c("Drain the tofu, carefully squeezing out exc...
# 4  c("Mix everything together and bring to a boil...

# %%
df_recipes.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 522517 entries, 0 to 522516
# Data columns (total 28 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   RecipeId                    522517 non-null  int64
#  1   Name                        522517 non-null  object
#  2   AuthorId                    522517 non-null  int64
#  3   AuthorName                  522517 non-null  object
#  4   CookTime                    439972 non-null  object
#  5   PrepTime                    522517 non-null  object
#  6   TotalTime                   522517 non-null  object
#  7   DatePublished               522517 non-null  object
#  8   Description                 522512 non-null  object
#  9   Images                      522516 non-null  object
#  10  RecipeCategory              521766 non-null  object
#  11  Keywords                    505280 non-null  object
#  12  RecipeIngredientQuantities  522514 non-null  object
#  13  RecipeIngredientParts       522517 non-null  object
#  14  AggregatedRating            269294 non-null  float64
#  15  ReviewCount                 275028 non-null  float64
#  16  Calories                    522517 non-null  float64
#  17  FatContent                  522517 non-null  float64
#  18  SaturatedFatContent         522517 non-null  float64
#  19  CholesterolContent          522517 non-null  float64
#  20  SodiumContent               522517 non-null  float64
#  21  CarbohydrateContent         522517 non-null  float64
#  22  FiberContent                522517 non-null  float64
#  23  SugarContent                522517 non-null  float64
#  24  ProteinContent              522517 non-null  float64
#  25  RecipeServings              339606 non-null  float64
#  26  RecipeYield                 174446 non-null  object
#  27  RecipeInstructions          522517 non-null  object
# dtypes: float64(12), int64(2), object(14)
# memory usage: 111.6+ MB

# %%
# Tampilkan baris di mana 'RecipeIngredientQuantities' mengandung huruf NA
df_with_na = df_recipes[df_recipes['RecipeIngredientQuantities'].apply(lambda x: pd.isna(x) or 'NA' in str(x))]

print(df_with_na.shape[0])
# Out:
# 180761

# %%
# Hapus baris di mana 'RecipeIngredientQuantities' mengandung huruf NA
df_recipes = df_recipes.drop(df_with_na.index)

df_recipes.head(5)
# Out:
#    RecipeId                                        Name  AuthorId AuthorName  \
# 0        38           Low-Fat Berry Blue Frozen Dessert      1533     Dancer
# 3        41              Carina's Tofu-Vegetable Kebabs      1586    Cyclopz
# 4        42                                Cabbage Soup      1538  Duckie067
# 7        45  Buttermilk Pie With Gingersnap Crumb Crust      1580  tristitia
# 8        46                     A Jad - Cucumber Pickle      1533     Dancer
#
#   CookTime PrepTime TotalTime         DatePublished  \
# 0    PT24H    PT45M  PT24H45M  1999-08-09T21:46:00Z
# 3    PT20M    PT24H  PT24H20M  1999-09-03T14:54:00Z
# 4    PT30M    PT20M     PT50M  1999-09-19T06:19:00Z
# 7    PT50M    PT30M   PT1H20M  1999-08-06T00:40:00Z
# 8      NaN    PT25M     PT25M  1999-08-11T19:48:00Z
#
#                                          Description  \
# 0  Make and share this Low-Fat Berry Blue Frozen ...
# 3  This dish is best prepared a day in advance to...
# 4  Make and share this Cabbage Soup recipe from F...
# 7  Make and share this Buttermilk Pie With Ginger...
# 8  Make and share this A Jad - Cucumber Pickle re...
#
#                                               Images   RecipeCategory  \
# 0  c("https://img.sndimg.com/food/image/upload/w_...  Frozen Desserts
# 3  c("https://img.sndimg.com/food/image/upload/w_...         Soy/Tofu
# 4  "https://img.sndimg.com/food/image/upload/w_55...        Vegetable
# 7  "https://img.sndimg.com/food/image/upload/w_55...              Pie
# 8                                       character(0)        Vegetable
#
#                                             Keywords  \
# 0  c("Dessert", "Low Protein", "Low Cholesterol",...
# 3  c("Beans", "Vegetable", "Low Cholesterol", "We...
# 4  c("Low Protein", "Vegan", "Low Cholesterol", "...
# 7  c("Dessert", "Healthy", "Weeknight", "Oven", "...
# 8      c("Thai", "Asian", "Free Of...", "< 30 Mins")
#
#                           RecipeIngredientQuantities  \
# 0                            c("4", "1/4", "1", "1")
# 3  c("12", "1", "2", "1", "10", "1", "3", "2", "2...
# 4                        c("46", "4", "1", "2", "1")
# 7  c("3/4", "1", "1", "2", "3", "1/4", "1", "1/2"...
# 8                  c("1/2", "5", "2", "1", "1", "1")
#
#                                RecipeIngredientParts  AggregatedRating  \
# 0  c("blueberries", "granulated sugar", "vanilla ...               4.5
# 3  c("extra firm tofu", "eggplant", "zucchini", "...               4.5
# 4  c("plain tomato juice", "cabbage", "onion", "c...               4.5
# 7  c("sugar", "margarine", "egg", "flour", "salt"...               4.0
# 8                          c("rice vinegar", "haeo")               5.0
#
#    ReviewCount  Calories  FatContent  SaturatedFatContent  CholesterolContent  \
# 0          4.0     170.9         2.5                  1.3                 8.0
# 3          2.0     536.1        24.0                  3.8                 0.0
# 4         11.0     103.6         0.4                  0.1                 0.0
# 7          3.0     228.0         7.1                  1.7                24.5
# 8          2.0       4.3         0.0                  0.0                 0.0
#
#    SodiumContent  CarbohydrateContent  FiberContent  SugarContent  \
# 0           29.8                 37.1           3.6          30.2
# 3         1558.6                 64.2          17.3          32.1
# 4          959.3                 25.1           4.8          17.7
# 7          281.8                 37.5           0.5          24.7
# 8            0.7                  1.1           0.2           0.2
#
#    ProteinContent  RecipeServings RecipeYield  \
# 0             3.2             4.0         NaN
# 3            29.3             2.0    4 kebabs
# 4             4.3             4.0         NaN
# 7             4.2             8.0         NaN
# 8             0.1             NaN       1 cup
#
#                                   RecipeInstructions
# 0  c("Toss 2 cups berries with sugar.", "Let stan...
# 3  c("Drain the tofu, carefully squeezing out exc...
# 4  c("Mix everything together and bring to a boil...
# 7  c("Preheat oven to 350°F.", "Make pie crust, u...
# 8  c("Slice the cucumber in four lengthwise, then...

# %%
# Menghapus baris yang tidak memiliki link gambar
df_recipes = df_recipes[df_recipes['Images'].notna()]

# Menghapus baris dengan nilai "(0)" atau karakter kosong pada kolom "Images"
df_recipes = df_recipes[df_recipes['Images'] != 'character(0)']

# Menghapus baris yang memiliki ReviewCount di bawah 10
df_recipes = df_recipes[df_recipes['ReviewCount'] > 5]

# Menghapus kolom-kolom yang diminta
columns_to_drop = ['AuthorName', 'CookTime', 'PrepTime', 'TotalTime', 'DatePublished', 'RecipeYield', 'Keywords', 'RecipeServings']
df_recipes = df_recipes.drop(columns=columns_to_drop, errors='ignore')

# %%
df_recipes = df_recipes.rename(columns={
    'FatContent': 'Fat',
    'SaturatedFatContent': 'SaturatedFat',
    'CholesterolContent': 'Cholesterol',
    'SodiumContent': 'Sodium',
    'CarbohydrateContent': 'Carbohydrate',
    'FiberContent': 'Fiber',
    'SugarContent': 'Sugar',
    'ProteinContent': 'Protein'
})

# %%
df_recipes['Description'] = df_recipes['Description'].replace('from Food.com', '', regex=True)

# %%
# Menampilkan nama yang duplikat
duplicate_names = df_recipes[df_recipes.duplicated(subset='Name', keep=False)]['Name'].unique()

# Menampilkan hasil
print("Nama yang duplikat:")
print(duplicate_names)
# Out:
# Nama yang duplikat:
# ['Carrot Cake' 'Blueberry Scones' 'Anzac Biscuits'
#  'Chocolate Zucchini Bread' 'Chocolate Chip Muffins' 'Homemade Butter'
#  'Brown Sugar Shortbread' 'Lemon Chicken' 'Olive Garden Pasta E Fagioli'
#  'Irish Soda Bread' 'Garlic Cauliflower' 'Fried Green Tomatoes'
#  'English Muffins' 'Egg Drop Soup' 'Hot Cocoa Mix' 'Oatmeal Muffins'
#  'Pumpkin Scones' 'Salsa' 'Spaghetti Pie' 'Taco Seasoning'
#  'Peanut Butter Bars' 'Rhubarb Crunch' 'Blackberry Pie' 'Rhubarb Squares'
#  "Grandma's Apple Muffins" 'Taco Seasoning Mix' 'Beer Can Chicken'
#  'Monster Cookies' 'Best Banana Bread' 'Quiche Lorraine' 'Sugar Cookies'
#  'Beef Stroganoff' 'Pumpkin Pie Squares' 'Pumpkin Chocolate Chip Muffins'
#  'Chicken Cheese Lasagna' 'Chicken Gumbo' 'Oven Fried Chicken'
#  'Oatmeal Chocolate Chip Cookies' 'Spaghetti Sauce'
#  'Chocolate Chip Cookies' 'Easy Crock Pot Chicken Cacciatore'
#  'Southern Cornbread' 'Cinnamon Raisin Bread' 'Chewy Chocolate Cookies'
#  'Molasses Cookies' 'Broccoli Casserole' 'Scalloped Potatoes and Ham'
#  'Cinnamon French Toast' 'Apple Muffins' 'Pavlova'
#  'Oatmeal Raisin Cookies' 'Apple Bread' 'Beer Bread'
#  'Sourdough French Bread' 'Pumpkin Muffins' 'Lemon Raspberry Muffins'
#  'Sour Cream Coffee Cake' 'Peanut Butter Kisses' 'Lasagna'
#  'Chicken Cordon Bleu' 'Grilled Salmon' 'Homemade Croutons'
#  'Garlic Potatoes' 'Red Cabbage Salad' 'Black Bean Dip'
#  'Cheesecake Cookies' 'Alfredo Sauce' 'Flourless Chocolate Cake'
#  'Pizza Dough' 'Chicken Stir-Fry' 'Chicken Marsala' 'Fried Rice'
#  'Macaroni Salad' 'Cheese Stuffed Shells' 'Teriyaki Marinade'
#  "Granny's Sugar Cookies" 'Asparagus Risotto' 'Baked Beans'
#  'Kentucky Butter Cake' 'Banana Oat Muffins' 'Vegan Macaroni and Cheese'
#  'Cream Cheese Pound Cake' 'Chocolate Mousse' 'Peanut Butter Sheet Cake'
#  'Sour Cream Banana Bread' 'Pizza Crust' 'Cheesecake' 'Coconut Cookies'
#  'Banana Nut Bread' 'Banana Muffins' 'Bourbon Steak' 'Banana Bread'
#  'Garlic Bread' 'Taco Soup' 'Sesame Broccoli' 'Guacamole' 'Banana Cake'
#  'Salmon Patties' 'Spinach Dip' 'Chocolate Cheesecake Muffins'
#  '5-Ingredient Strawberry Pie' 'Pickled Carrots' 'Norwegian Apple Cake'
#  'Peanut Butter Cookies' 'Brownies' 'Jamaican Jerk Pork' 'Broccoli Salad'
#  'Breakfast Casserole' 'Greek Lentil Soup' 'No-Fail Pie Crust'
#  'Portuguese Sweet Bread' 'Lamb Korma' 'Cranberry Chutney'
#  'Gingerbread Waffles' 'Sweet Potato Casserole' 'Cashew Chicken'
#  'Cabbage Casserole' 'Hot German Potato Salad' 'Rice Salad' 'Granola Bars'
#  'Oatmeal Cookies' 'Pina Colada' 'Apple Crisp' 'Fluffy Frosting'
#  'Cheesy Garlic Bread' 'Reuben Casserole' 'Bisquick Clone'
#  'Homemade Bread' 'Oreo Cookie Dessert' 'Mongolian Beef' 'Tuna Casserole'
#  'Cucumber Salad' 'Pesto' 'Cranberry Scones' 'Snickerdoodles'
#  'Cornbread Taco Bake' 'Oatmeal Pancakes' 'Pumpkin Bread'
#  'Texas Sheet Cake' 'Bruschetta' 'Vegan Pumpkin Pie' 'Cajun Seasoning Mix'
#  'Fruit Dip' 'Jalapeno Poppers' 'Pizza Popcorn' 'Caramel Popcorn'
#  'Enchilada Casserole' 'Herbed Pork Chops' 'Nanaimo Bars'
#  'Cake Mix Cookies' 'Oatmeal Cranberry Cookies'
#  'Oven Fried Sesame Chicken' "Santa's Whiskers" 'Lentil Soup'
#  'Sweet and Sour Sauce' 'Brownie Trifle' 'Almond Chicken'
#  'Greek Pasta Salad' 'Fluffy Pancakes' 'Chicken Lo Mein'
#  'Curried Couscous' 'Carrot Cookies' 'Honey Butter' 'Fried Cabbage'
#  'Zucchini Bread' 'Easy Beer Bread' 'Parmesan Chicken Breasts'
#  'Blonde Brownies' 'Creamed Spinach' 'Green Tomato Bread' 'Caramel Corn'
#  'Monkey Bread' 'Flourless Peanut Butter Cookies' 'Mexican Lasagna'
#  'Bavarian Apple Torte' 'Pork Chops Supreme' 'Meatballs'
#  'Creamy Chicken Broccoli Bake' 'Mexican Tortilla Casserole'
#  'Cream Cheese Cookies' 'Crepes' 'Chicken Enchiladas'
#  'Creamy Chocolate Frosting' 'Strawberry Bread' 'Chicken Stir Fry'
#  'Rolo Cookies' 'Hot Milk Cake' 'Easy Guacamole' 'Caramel Squares'
#  'Mexican Manicotti' 'Dumplings' 'Cajun Chops' 'Tartar Sauce' 'Picadillo'
#  'String Spaghetti Pie' 'Sausage Bread' 'Steak Diane'
#  'Banana Coconut Muffins' 'Banana Milkshake' 'Blackberry Cobbler'
#  'Cordon Bleu Casserole' 'Morning Glory Muffins'
#  'Hungarian Cucumber Salad' 'Blueberry Bundt Cake' 'Caramel Apple Salad'
#  'Green Rice' 'Melt in Your Mouth Banana Bread' 'Ultimate Oatmeal Cookies'
#  'Pecan Pie Mini Muffins' 'Taco Casserole' 'Bran Muffins' 'Cucumber Salsa'
#  'Dill Dip' 'Whole Wheat Pancakes' 'Crock Pot Chicken Curry' 'Apple Cake'
#  'Cinnamon Muffins' 'Peanut Butter Balls' 'Lemon Sauce' 'Chicken Stew'
#  'Chickpea Salad' 'Mexican Cornbread' 'Honey Cornbread'
#  'Banana Bran Muffins' 'Butter Chicken' 'Play Dough' 'Chocolate Cobbler'
#  'Applesauce Cake' 'Pork Marinade' 'Italian Wedding Soup' 'Garlic Shrimp'
#  'Slow Cooker Lasagna' 'Sweetened Condensed Milk' 'Peanut Butter Brownies'
#  'Raisin Scones' 'Lemon Garlic Chicken' 'Chicken Paprikash'
#  'Apple Pancakes' 'Peanut Butter Icing' 'Herb Roasted Turkey'
#  'Banana Pancakes' 'Lofthouse Cookies' 'Strawberry Julius' 'Apple Salad'
#  'Cheeseburger Pasta' 'Spiced Couscous' 'Creamy Coleslaw'
#  'Lemon Meringue Pie' 'Blueberry Pie' 'Garlic Chicken Pizza'
#  'Butterfinger Cookies' 'Apricot Carrots' 'Salmon Chowder'
#  'Glazed Meatloaf' 'Bananas Foster' 'Crock Pot Caramelized Onions'
#  'Chicken Salad' 'Chocolate Pound Cake' 'Tender Sauteed Zucchini'
#  'Enchilada Pie' 'Chicken Tikka Masala' 'Szechuan Shrimp' 'Baked Oatmeal'
#  'Pancakes' 'Greek Tomato Salad' 'Vietnamese Chicken Salad'
#  'Tex-Mex Pork Chops' 'Oven Barbecued Chicken'
#  'Chocolate Chip Oatmeal Cookies' 'Amish White Bread'
#  'Macaroni and Tomatoes' 'Roasted Red Potatoes' 'Baked Ziti'
#  'Simple Syrup' 'Honey Wheat Bread' 'Simple Scallops'
#  'Herb Roasted Potatoes' 'German Potato Salad' 'Salsa Chicken'
#  'Applesauce Muffins' 'Ice Cream Sandwich Dessert' 'Cinnamon Coffee Cake'
#  'Pot Roast' 'White Texas Sheet Cake' 'Buttermilk Biscuits'
#  'Cheddar-Garlic Biscuits' 'Fajita Seasoning Mix' 'London Broil'
#  'Cream Cheese Brownies' 'Cilantro Rice' 'Greek Marinade' 'Baked Salmon'
#  'Glazed Lemon Loaf' 'Chocolate Covered Strawberries' 'Buffalo Wings'
#  'Baked Potato Soup' 'Marinated Cucumbers' 'Spanish Rice' 'Cream Scones'
#  'Lemon Crinkle Cookies' 'Cauliflower Casserole' 'Sesame Asparagus'
#  'Corn Muffins' 'Amish Baked Oatmeal' 'Taco Salad' 'Chocolate Frosting'
#  'Enchilada Sauce' 'Peach Cobbler' 'Sweet and Sour Skillet Chicken'
#  'Zucchini Pie' 'Gumbo' 'Flour Tortillas' 'Pork Fried Rice'
#  'Cookie Dough Brownies' 'Potato Curry' 'Homemade Yogurt'
#  'Antipasto Pasta Salad' 'Peanut Butter Pie' 'English Toffee'
#  'Garlicky Green Beans' 'Raspberry Sauce' 'Dump Cake' 'Eggnog Muffins'
#  'Cajun Burgers' 'Mexican Hot Chocolate' 'No-Bake Cookies' 'Egg Bread'
#  'White Chocolate Mousse' 'Three Bean Salad' 'Blueberry Streusel Muffins'
#  'White Chocolate Macadamia Cookies' 'Butternut Squash Soup'
#  'Caramel Popcorn Balls' 'Chinese Spaghetti'
#  'Peanut Butter Banana Cookies' 'Mexican Rice' 'Easy Peach Cobbler'
#  'Blueberry Oat Muffins' 'Spicy Guacamole' 'Rice Pudding'
#  'Pumpkin Pancakes' 'Spicy Sweet Potatoes' 'Pecan Pie Bars'
#  'Cake Mix Banana Nut Bread' 'Easy Dinner Rolls' 'Black Bean Mango Salsa'
#  'Tomato Soup' 'My Favorite Chocolate Chip Cookies'
#  'Russian Salad Dressing' 'Breakfast Bars' 'Turkey Meatloaf'
#  'Orange Muffins' 'Chicken Noodle Soup' 'Crock Pot Pulled Pork'
#  'Creamy Chicken Casserole' 'Lemon Broccoli' 'Butter Pecan Cake'
#  'Crab Cakes' 'Greek Salad Dressing' 'Pineapple Upside Down Cake'
#  'Honey Baked Chicken' 'Crock Pot Chicken Cacciatore' 'Meatloaf'
#  'Cheese Soup' 'Gingerbread Pancakes' 'Rocky Road Squares'
#  'Balsamic Vinaigrette' 'Cranberry-Orange Nut Bread' 'Lemon Pudding Cake'
#  'Zucchini Cupcakes' 'Raspberry Lemon Muffins' 'Pumpkin Cookies' 'Waffles'
#  'Pumpkin Spice Cake' 'Cranberry Coffee Cake' 'Garlic Green Beans'
#  'Turkey Pot Pie' 'Italian Salad Dressing' 'Snickerdoodle Cookies'
#  'Mahogany Chicken Wings' 'Corn Dog Muffins' 'Sweet Potato Bake'
#  'Colcannon' 'Sesame Chicken' 'Enchilada Soup' 'Rum Cake'
#  'Broccoli Parmesan' 'Apple Pie' 'Cola Roast' 'Skillet Cornbread'
#  'Oreo Ice Cream Cake' 'Bourbon Chicken' 'Sausage Balls' 'Lemon Curd'
#  'Sloppy Joes' 'Cocoa Brownies' 'Green Bean Casserole'
#  'Cinnamon Swirl Coffee Cake' 'Garlic Mashed Potatoes'
#  'Blueberry Jello Salad' 'Easy Taco Casserole' 'Saffron Rice'
#  'Corn Casserole' 'Raspberry Vinaigrette' 'Key Lime Pie'
#  'Old Fashioned Peanut Butter Cookies' 'Vegetable Chowder'
#  'Teriyaki Sauce' 'Mexican Casserole' 'Strawberry Cow'
#  'The Best Banana Bread' 'Kielbasa Casserole' 'Buttermilk Pancakes'
#  'Roasted Asparagus' 'Greek Chicken Salad'
#  'Peanut Butter Chocolate Chip Cookies' 'Coffee Cake Muffins' 'Pikelets'
#  'Scones' 'Chocolate Chip Scones' 'Strawberry Pie' 'Honey Glazed Carrots'
#  'Peanut Butter Bread' 'Baked Parmesan Fish' 'Banana Oatmeal Cookies'
#  'Beef Taco Bake' 'Artichoke Chicken' 'Yeast Waffles' 'Hungarian Goulash'
#  'Pound Cake' 'Moist Banana Bread' 'Coconut Basmati Rice'
#  'Lemon Sour Cream Pound Cake' 'Stuffed Mushrooms' 'Carrot Souffle'
#  'Thai Turkey' 'Cream Cheese Frosting' 'Coleslaw' 'Strawberry Jam'
#  'Moroccan Mint Tea' 'Challah' "Minnesota's Favorite Cookies"
#  'Chewy Cranberry Oatmeal Cookies' 'Lemon Chess Pie' 'Lemon Squares'
#  'Tuna Patties' 'Boston Cream Pie' 'Sliced Baked Potatoes'
#  'Cranberry Apple Muffins' 'Garlic Roasted Potatoes'
#  'Pumpkin Chocolate Chip Cookies' 'Whole Wheat Banana Bread'
#  'Aussie Chicken' 'French Baguette' 'Stuffed Bell Peppers'
#  'Hawaiian Coleslaw' 'Cheese Ball' 'French Toast' 'Strawberry Mousse'
#  'Greek Pita Bread' 'Apple Crumble' 'Date Squares' 'Greek Seasoning Mix'
#  'Banana Loaf Cake' 'Blueberry Cream Cheese Muffins' 'Tomato Salad'
#  'Green Tomato Casserole' 'Lemon Rice Pilaf' 'Garlic Chicken'
#  'German Chocolate Cake Mix Cookies' 'Self-Saucing Chocolate Pudding'
#  'BBQ Chicken Pizza' 'Brussels Sprouts' 'Broccoli Cheese Soup'
#  'Mango Bread' 'Roasted Parmesan Potatoes' 'Baking Powder Biscuits'
#  'Peanut Butter Banana Muffins' 'Blackened Chicken'
#  'Italian Vegetable Soup' 'Chicken Piccata' 'Granola' 'Cornbread'
#  'Almond Tea' 'Macadamia Nut Cookies' 'Honey Oatmeal Bread'
#  'Cheesy Scalloped Potatoes' 'Chocolate Crinkle Cookies' 'Blondies'
#  'Strawberry Coffee Cake' 'Chocolate Chip Pudding Cookies'
#  'Vegan French Toast' 'Vegan Chocolate Chip Cookies' 'Peanut Butter Fudge'
#  'Cinnamon Rolls' 'Caramel Sauce' 'Spaghetti Pizza Pie' 'Applesauce'
#  'Pistachio Cake' 'Spinach Salad' 'Deviled Eggs' 'Mexican Chicken'
#  'Mexican Salad' 'Tea Biscuits' 'Salmon Cakes' 'Pot Sticker Dipping Sauce'
#  'Rosemary Pork Chops' 'Hot Fudge Sauce' 'Honey Sesame Pork Tenderloin'
#  'Beef Keema' 'Greek Baked Fish' 'Banana Berry Smoothie' 'Biscuits'
#  'Eclair Cake' 'Pork Chop Casserole' 'Eggnog Pound Cake' 'Raspberry Bars'
#  'Strawberry Shortcake Muffins' 'Flaky Deli Slices' 'Flan' 'Mai Tai'
#  'Hot and Sour Soup' 'Spicy Sweet Potato Fries' 'Sourdough Pancakes'
#  'Asparagus Breakfast Casserole' 'Pizza Sauce'
#  'Chicken and Stuffing Casserole' 'Spinach Pie' 'Ham and Noodle Casserole'
#  'Hamburger Steak and Gravy' 'Cornbread in a Skillet' 'Rice Pilaf'
#  'Banana Oatmeal' 'Strawberry Sorbet' 'Moroccan Chicken'
#  'Black Bean and Corn Soup' 'Green Beans Au Gratin'
#  'Blueberry Cream Cheese Pound Cake' 'Frito Corn Salad'
#  'Cajun Remoulade Sauce' 'Pecan Bars' 'Yellow Cake' 'Shrimp Pad Thai'
#  'Pico De Gallo' 'Pork Chops With Mushroom Sauce'
#  'Raspberry Cream Cheese Coffee Cake' 'Muffuletta Sandwich' 'Croutons'
#  'Rhubarb Crisp' 'Cornucopia Salad' 'Chicken Surprise'
#  'Blueberry Coffee Cake' 'Egg Salad' 'Avocado Dip'
#  'Chocolate Cream Cheese Pound Cake' 'Country White Bread'
#  'Oven Fried Parmesan Potatoes' 'Thousand Island Dressing'
#  'Sausage and Potato Soup' 'Crusty French Bread' 'Yummy Chicken'
#  'Hawaiian Chicken' 'Sticky Chicken' 'Glazed Carrots' 'Spiced Carrots'
#  'Italian Sausage Soup' "Mom's Macaroni &amp; Cheese"
#  'Secret Recipe Chocolate Chip Cookies' 'Basic Waffles'
#  'Dipped Gingersnaps' 'Chocolate Pecan Pie' 'Green Beans'
#  'Garlic Lime Chicken' 'Butterscotch Brownies' 'Honey Dijon Chicken'
#  'White Pizza' 'Cream Cheese Sugar Cookies' 'Sweet and Sour Dipping Sauce'
#  'Nutty Banana Oatmeal' 'Blue Ribbon Peanut Butter Cookies'
#  'Szechuan Noodles' 'Fresh Peach Pie' 'Date Bars'
#  'Cranberry Streusel Muffins' 'Couscous Salad' 'Pizza Casserole'
#  'Peanut Butter Banana Bread' 'Peach Muffins' 'Cherry Chip Scones'
#  'Grilled Pork Chops' 'Avocado Nut Bread' 'Picnic Potato Salad'
#  'Award Winning Guacamole' 'Green Beans Parmesan' 'Shrimp Scampi'
#  'Hot Pizza Dip' 'Curried Chicken Salad' 'Egg and Bacon Tarts'
#  'Blueberry Banana Bread' 'Magnolia Bakery Vanilla Cupcakes'
#  'Turkish Coffee' 'Lemon Tea Bread' 'Peanut Butter and Jelly Muffins'
#  'Crock Pot French Dip Sandwiches' 'Chocolate Bread Pudding'
#  'Whole Wheat Bread' 'Mexican Coffee' 'Deviled Carrots'
#  'Creamy White Chili' 'Chicken Crepes' 'Healthy Peanut Butter Balls'
#  'Vegetarian Black Bean Soup' 'Peachy Chicken' 'Maple Oatmeal Muffins'
#  'Banana Smoothie' 'Gluten Free Tortillas' 'Chocolate Pudding'
#  'Peanut Butter Granola' 'Sweet Potato Souffle' 'Avocado Ranch Dressing'
#  'Pasta Salad' 'Chocolate Chip Cookie Bars' 'Warm Winter Lemon Cake'
#  'Wilton Buttercream Icing' 'Moroccan Carrot Salad' 'Congo Bars'
#  'Cilantro Lime Rice' 'Honeyed Carrots' 'Cherry Vanilla Oatmeal'
#  'Easy Peanut Butter Cookies' 'Barbecue Baked Lentils' 'Turkey Burgers'
#  'Homemade Breakfast Sausage' 'Sweet Potato Fries' 'Marinated Mushrooms'
#  'Pastitsio' 'Twice-Baked Potato Casserole' 'German Cucumber Salad'
#  'Indian Cucumber Salad' 'Cajun Chicken Strips' 'Broccoli-Rice Casserole'
#  'Asian Grilled Chicken' 'Marinated Olives' 'Pink Lemonade' "S'more Bars"
#  'Chicken Tacos' 'Fudgy Brownies' 'Vegetarian Sausage Rolls'
#  'Cinnamon Toast' 'Japanese Cucumber Salad' 'Eggnog Pancakes'
#  'Beef Tomato' 'Pumpkin Pie Oatmeal' 'Buffalo Chicken Soup'
#  'Whole Wheat Chocolate Chip Cookies' 'Roasted Brussels Sprouts'
#  'Sausage Potato Bake' 'Egg Casserole for Two' 'Orange Butter'
#  'Fish and Chips' 'Salisbury Steak With Mushroom Gravy'
#  'Oatmeal Spice Muffins' 'Black Bean Salad' 'Berry Smoothie' 'Pork Chops'
#  'Tortilla Pie' 'Dill Pickle Dip' 'Curried Lentil and Vegetable Soup'
#  'Jalapeno Popper Spread' 'Ginger Cookies' 'Baked Chicken Chimichangas'
#  'Breakfast Burritos' 'Mango Lassi' 'Bay Breeze' 'Pumpkin Trifle'
#  'Slow Cooker Chicken and Dumplings' 'Moist and Delicious Banana Bread'
#  'Black Bean Brownies (Gluten Free)' 'Garlic Cheese Bread'
#  'Sauteed Zucchini' 'Beef Burgers' 'Banana Pancake' 'Pineapple Muffins'
#  'Pizza Burgers' 'Grilled Flank Steak' 'Mashed Potatoes Supreme'
#  'Coconut Rice' 'Garlic Butter']

# %%
# Menghapus baris dengan nama yang duplikat
df_recipes = df_recipes.drop_duplicates(subset='Name', keep='first')

# %%
#check
check_rows = df_recipes.loc[df_recipes['Name'] == 'Hawaiian Chicken']
check_rows.head()
# Out:
#        RecipeId              Name  AuthorId  \
# 96660    102120  Hawaiian Chicken     80353
#
#                                              Description  \
# 96660  OK, it's the sauce that makes the chicken. Rea...
#
#                                                   Images RecipeCategory  \
# 96660  c("https://img.sndimg.com/food/image/upload/w_...        Chicken
#
#                               RecipeIngredientQuantities  \
# 96660  c("3", "1/4", "1/4", "1/2", "1/3", "1/2", "1/4...
#
#                                    RecipeIngredientParts  AggregatedRating  \
# 96660  c("chicken", "ketchup", "soy sauce", "chicken ...               4.0
#
#        ReviewCount  Calories   Fat  SaturatedFat  Cholesterol  Sodium  \
# 96660         10.0     660.0  34.4           9.8        170.1  1021.3
#
#        Carbohydrate  Fiber  Sugar  Protein  \
# 96660          30.4    0.3   26.5     44.4
#
#                                       RecipeInstructions
# 96660  c("Mix sauce ingredients in bowl; generously c...

# %%
def map_str_to_list(value):
    if isinstance(value, str):
        pattern = re.compile(r'\"([^"]+)\"')
        return pattern.findall(value)
    else:
        return value

def map_for_series(series):
    return series.apply(map_str_to_list)

# %%
modify_col_list = ['RecipeIngredientQuantities', 'RecipeIngredientParts', 'RecipeInstructions']
df_recipes = df_recipes.apply(lambda x: map_for_series(x) if x.name in modify_col_list else x)

# %%
df_recipes['Ingredients'] = df_recipes.apply(
    lambda row: [f"{row['RecipeId']} \"{ingredient}\"" for ingredient in row['RecipeIngredientParts']],
    axis=1
)

# %%
#Menggabungkan
df_recipes['Ingredients'] = df_recipes.apply(lambda row: [f'{quantity} "{ingredient}"' for quantity, ingredient in zip(row['RecipeIngredientQuantities'], row['RecipeIngredientParts'])], axis=1)

# %%
df_recipes['Instructions'] = df_recipes['RecipeInstructions'].apply(lambda x: [f'"{step}"' for step in x])

# %%
# Menghapus kolom-kolom yang diminta
columns_drop = ['RecipeIngredientQuantities', 'RecipeIngredientParts', 'RecipeInstructions']
df_recipes = df_recipes.drop(columns=columns_drop, errors='ignore')

# %%
df_recipes.head(5)
# Out:
#     RecipeId                                    Name  AuthorId  \
# 4         42                            Cabbage Soup      1538
# 11        49                Chicken Breasts Lombardi    174711
# 16        54                             Carrot Cake      1535
# 18        56                          Buttermilk Pie      1581
# 20        58  Low-Fat Burgundy Beef & Vegetable Stew      1533
#
#                                           Description  \
# 4           Make and share this Cabbage Soup recipe .
# 11  Make and share this Chicken Breasts Lombardi r...
# 16  This is one of the few recipes my husband ever...
# 18  This recipe was originally noted by my wife on...
# 20  Make and share this Low-Fat Burgundy Beef & Ve...
#
#                                                Images  RecipeCategory  \
# 4   "https://img.sndimg.com/food/image/upload/w_55...       Vegetable
# 11  c("https://img.sndimg.com/food/image/upload/w_...  Chicken Breast
# 16  c("https://img.sndimg.com/food/image/upload/w_...         Dessert
# 18  c("https://img.sndimg.com/food/image/upload/w_...             Pie
# 20  c("https://img.sndimg.com/food/image/upload/w_...            Stew
#
#     AggregatedRating  ReviewCount  Calories   Fat  SaturatedFat  Cholesterol  \
# 4                4.5         11.0     103.6   0.4           0.1          0.0
# 11               5.0         21.0     627.7  24.9          13.0        203.0
# 16               5.0         17.0     522.6  27.1           4.9         69.8
# 18               5.0        171.0     395.9  19.1           9.8        101.5
# 20               4.5          7.0     280.1   6.0           1.5         66.9
#
#     Sodium  Carbohydrate  Fiber  Sugar  Protein  \
# 4    959.3          25.1    4.8   17.7      4.3
# 11   848.9          13.7    0.6    2.0     57.9
# 16   534.8          67.0    1.6   47.9      5.0
# 18   269.8          52.2    0.7   39.9      5.0
# 20   591.5          22.4    6.1    9.2     29.8
#
#                                           Ingredients  \
# 4   [46 "plain tomato juice", 4 "cabbage", 1 "onio...
# 11  [2 "fresh mushrooms", 2 "butter", 12 "boneless...
# 16  [3 "carrots", 4 "eggs", 1 1/4 "white sugar", 2...
# 18  [1/2 "butter", 1 1/2 "margarine", 3 "sugar", 3...
# 20  [1 1/2 "beef eye round", 1 "dried thyme leaves...
#
#                                          Instructions
# 4   ["Mix everything together and bring to a boil....
# 11  ["Cook mushrooms in 2 tbsp butter in a large  ...
# 16  ["Beat together the eggs, oil, and white sugar...
# 18  ["Preheat oven to 400°F.", "Beat the butter an...
# 20  ["Trim fat from beef, cut into 1-inch pieces."...

# %%
# Menampilkan total baris
total_rows = df_recipes.shape[0]
print(f"Total baris dalam dataset: {total_rows}")
# Out:
# Total baris dalam dataset: 28246

# %% [markdown]
# ------------------------------------------

# %% [markdown]
# # Reviews

# %%
# Menampilkan total baris
total_rows = df_reviews.shape[0]
print(f"Total baris dalam dataset: {total_rows}")
# Out:
# Total baris dalam dataset: 1401982

# %%
df_reviews = pd.merge(df_reviews, df_recipes[['RecipeId', 'Name']], on='RecipeId', how='left')

# %%
name_column = df_reviews.pop('Name')
df_reviews.insert(1, 'Name', name_column)

# %%
# Menghapus baris yang tidak memiliki link gambar
df_reviews = df_reviews[df_reviews['Name'].notna()]

# %%
df_reviews.head(5)
# Out:
#     ReviewId                                              Name  RecipeId  \
# 5         17                      Spinach and Strawberry Salad      5221
# 6         19  Neiman-Marcus $250 Chocolate Chip Cookies Recipe     13307
# 10        24                           Greek Spinach Triangles       278
# 11        25                   Leek, Tomato, Goat Cheese Pizza      3431
# 12        26                      Spinach and Strawberry Salad      5221
#
#     AuthorId        AuthorName  Rating  \
# 5       2046  Gay Gilmore ckpt       4
# 6       2046  Gay Gilmore ckpt       5
# 10      1773     Malarkey Test       4
# 11      2046  Gay Gilmore ckpt       5
# 12      2369    William Hakala       5
#
#                                                Review         DateSubmitted  \
# 5              love it, but without the bean sprouts.  2000-05-08T11:08:00Z
# 6   chewy goodness, not crispy at all. i even thre...  2000-05-21T16:59:00Z
# 10   a little greasy, but a huge hit with the guests.  2000-03-13T19:53:00Z
# 11  leeks on a pizza?!  it was really delicious.  ...  2000-04-07T11:06:00Z
# 12  I deleted the bean sprouts and replaced them w...  2000-07-18T13:36:56Z
#
#             DateModified
# 5   2000-05-08T11:08:00Z
# 6   2000-05-21T16:59:00Z
# 10  2000-03-13T19:53:00Z
# 11  2000-04-07T11:06:00Z
# 12  2000-07-18T13:36:56Z

# %%
df_reviews.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 580344 entries, 5 to 1401980
# Data columns (total 9 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   ReviewId       580344 non-null  int64
#  1   Name           580344 non-null  object
#  2   RecipeId       580344 non-null  int64
#  3   AuthorId       580344 non-null  int64
#  4   AuthorName     580344 non-null  object
#  5   Rating         580344 non-null  int64
#  6   Review         580215 non-null  object
#  7   DateSubmitted  580344 non-null  object
#  8   DateModified   580344 non-null  object
# dtypes: int64(4), object(5)
# memory usage: 44.3+ MB

# %%
columns_to_drop = ['AuthorName']
df_reviews = df_reviews.drop(columns=columns_to_drop, errors='ignore')

# %%
# Menampilkan total baris
total_rows = df_reviews.shape[0]
print(f"Total baris dalam dataset: {total_rows}")
# Out:
# Total baris dalam dataset: 580344

# %% [markdown]
# # Save File

# %%
# df_reviews.to_csv('/content/drive/MyDrive/Capstone/reviews_reduce.csv', index=False)

# %%
# df_recipes.to_csv('/content/drive/MyDrive/Capstone/recipes_reduce.csv', index=False)
